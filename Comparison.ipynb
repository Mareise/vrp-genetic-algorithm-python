# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('statistics_fixed_iteration200.csv')

# %%
df
# Out:
#            cost  popsize  iterations    runtime
# 0   1770.332110       10         200   0.414126
# 1   1623.026035       20         200   0.742280
# 2   1484.613548       30         200   1.056947
# 3   1606.750800       40         200   1.937082
# 4   1457.298663       50         200   1.947607
# 5   1391.117553       60         200   2.469526
# 6   1249.349247       70         200   2.790780
# 7   1388.112463       80         200   3.481997
# 8   1326.845965       90         200   4.007581
# 9   1335.648895      100         200   4.201522
# 10  1423.971099      110         200   4.215567
# 11  1257.386741      120         200   5.895230
# 12  1464.736398      130         200   6.419146
# 13  1338.888565      140         200   6.876197
# 14  1500.477272      150         200   7.130365
# 15  1431.033007      160         200   8.248667
# 16  1342.219739      170         200   8.177889
# 17  1275.231234      180         200   8.313838
# 18  1294.243366      190         200   8.506579
# ...

# %%
plt.figure(figsize=(20,6))
plt.plot(df['popsize'], df['cost'], marker='o', linestyle='-', color='b', label='Cost vs Population')
plt.title('Cost vs Population')
plt.xlabel('Population')
plt.ylabel('Cost')
plt.legend()
plt.grid(True)
plt.show()
